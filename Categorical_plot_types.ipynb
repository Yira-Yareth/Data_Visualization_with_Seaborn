# %% [markdown]
# ## Categorical plot types
#
# Categorical plots that show each observation can be very powerful tools for gaining insight into your data.
#
#
# Seaborn also supports many plot types with categorical data. Categorical data is data which includes a limited or fixed number of values and is most useful when combined with numeric data.

# %% [markdown]
#  We will continue to look at the 2010 School Improvement data and segment the data by the types of school improvement models used.

# %%
#Importing packages
import io 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading csv
df=pd.read_csv("datasets//schoolimprovement2010grants.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 757 entries, 0 to 756
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      757 non-null    int64
#  1   School Name     757 non-null    object
#  2   City            757 non-null    object
#  3   State           757 non-null    object
#  4   District Name   757 non-null    object
#  5   Model Selected  757 non-null    object
#  6   Award_Amount    757 non-null    int64
#  7   Region          747 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 47.4+ KB
# None

# %%
# Create a stripplot of the Award_Amount with the Model Selected on the y axis with jitter enabled
sns.stripplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         jitter=True)

plt.show()

# %% [markdown]
# Seaborn's stripplot() shows every observation in the dataset. In some cases, it can be difficult to see individual data points.

# %%
#Create a swarmplot() of the same data, but also include the hue by Region
sns.swarmplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         hue='Region')

plt.show()
# Out:
# C:\Users\Yira\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 34.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Yira\Anaconda\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# We can plot a more sophisticated visualization of all the data using a swarmplot(). This plot uses a complex algorithm to place the observations in a manner where they do not overlap. The downside of this approach is that the swarmplot() does not scale well to large datasets.

# %% [markdown]
# ## boxplots, violinplots and lvplots

# %%
# Create and display a boxplot of the data with Award_Amount on the x axis and Model Selected on the y axis.
sns.boxplot(data=df,
         x='Award_Amount',
         y='Model Selected')

plt.show()
plt.clf()

# %% [markdown]
# This plot is used to show several measures related to the distribution of data, including the median, upper and lower quartiles, as well as outliers.

# %%
# Create and display a similar violinplot of the data, but use the husl palette for colors.
sns.violinplot(data=df,
         x='Award_Amount',
         y='Model Selected',
         palette='husl')

plt.show()
plt.clf()

# %% [markdown]
# ### barplots, pointplots and countplots
#
# The final group of categorical plots are barplots, pointplots and countplot which create statistical summaries of the data. The plots follow a similar API as the other plots and allow further customization for the specific problem at hand.

# %%
# Show a countplot with the number of models used with each region a different color

sns.countplot(data=df,
         y="Model Selected",
         hue="Region")

plt.show()
plt.clf()

# %%
# Create a pointplot with the df dataframe and Model Selected on the x-axis and Award_Amount on the y-axis.
# Use a capsize in the pointplot in order to add caps to the error bars

sns.pointplot(data=df,
         y='Award_Amount',
         x='Model Selected',
         capsize=.1)

plt.show()
plt.clf()

# %%
#Create a barplot with the same data on the x and y axis and change the color of each bar based on the Region column.
sns.barplot(data=df,
         y='Award_Amount',
         x='Model Selected',
         hue="Region")

plt.show()
plt.clf()

# %% [markdown]
# The pointplot and barplot can be useful visualizations for understanding the variations of categorical data.
